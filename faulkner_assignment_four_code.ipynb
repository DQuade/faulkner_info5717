# %%
##1.1 sql table creation and test insert

# %%
CREATE TABLE persons (
    personid int AUTO_INCREMENT PRIMARY KEY,
    username varchar(50) NOT NULL,
    screenname varchar(50) NOT NULL, 
    userlocation varchar(50), 
    userdescription varchar(1000),
    thenumberoffollowers int,
    thenumberofFriends int,
    thenumberofstatuses int,
    userurl varchar(200)  
    );
INSERT INTO persons(username, screenname, userlocation, userdescription, thenumberoffollowers, thenumberofFriends, thenumberofstatuses, userurl)
VALUES('james', 'james1', 'Houston', 'bio', 11,11, 11, 'www');
# Out:
#   File "<ipython-input-2-d3c32970b843>", line 1
#     CREATE TABLE persons (
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##1.2

# %%
import tweepy
import csv
import mysql.connector
import pymysql

connectionInstance = pymysql.connect(host='localhost', database='twit', user='root', password= 'Sketchy01', charset='utf8mb4',cursorclass=pymysql.cursors.DictCursor)
	#cursorClass='pymysql.cursor.DirectCursor )


CONSUMER_KEY = 'u7L1lnR7HN85dn1qnTFO1cegb'
CONSUMER_SECRET = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
access_token = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
access_secret = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)


csvFile = open('tweets.csv', 'a', encoding="utf-8")

csvWriter = csv.writer(csvFile)

names = ['MeanGreenSoccer', 'UNTSocial', 'UHClearLake', 'BarackObama', 'tommycaldwell1', 'Dave_Graham_','NHukkataival','EpicTVClimbing','DanzigerDeLlano','5ten']

def test(x):

	for name in x:
		public_tweets = api.user_timeline(screen_name=name, count = 1)
   
		for tweet in public_tweets: 

			nam = tweet.user.name
			sname = tweet.user.screen_name
			udesc= tweet.user.description
			followers = tweet.user.followers_count
			friends = tweet.user.friends_count
			numStat = tweet.user.statuses_count
			local = tweet.user.location
			usurl = tweet.user.url
			print (nam, sname)

			try:
				cursorObject = connectionInstance.cursor()
				sqlShowTablesCommand= 'show tables'
				cursorObject.execute(sqlShowTablesCommand)
				value = [nam, sname, local, udesc, followers, friends, numStat, usurl]
				cursorObject.execute('INSERT INTO persons ( username, screenname, userlocation, userdescription, thenumberoffollowers, thenumberofFriends, thenumberofstatuses, userurl) values(%s, %s, %s, %s, %s, %s, %s, %s)',value)
				connectionInstance.commit()
			except Exception as e:
				print ('eceltion occured:{}'.format(e))
	connectionInstance.close()
test (names)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0a7df695207d> in <module>
#       1 import tweepy
#       2 import csv
# ----> 3 import mysql.connector
#       4 import pymysql
#       5
#
# ModuleNotFoundError: No module named 'mysql'

# %%
##1.3

# %%
import tweepy
import csv

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt


CONSUMER_KEY = 'u7L1lnR7HN85dn1qnTFO1cegb'
CONSUMER_SECRET = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
access_token = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
access_secret = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)


csvFile = open('ua.csv', 'a')

csvWriter = csv.writer(csvFile)

follower = []
friends = []

for  tweet in tweepy.Cursor(api.followers_ids, id='NHukkataival', count=5000).pages():
    nam = tweet
    follower = nam
    print(follower)
   
for  tweet in tweepy.Cursor(api.friends_ids, id='NHukkataival', count=5000).pages():
    nam = tweet
    friends = nam
    print(friends)

g = nx.Graph()
g.add_nodes_from(friends)
g.add_edge(1110294564, '')



print (nx.info(g))
nx.draw(g)
plt.show()
# Out:
# [81106463, 1196977123606564866, 1064349617402331137, 1196638546972401665, 1196159968761798657, 1178787360764506112, 1194122605336219648, 4517868501, 365856032, 1191193141505740800, 1189950435827695616, 712287033390211073, 1186707846315905024, 1189890403929088002, 1193552111553982465, 1125809011301986304, 548877886, 3401899911, 1114753187536203776, 312984396, 857997504314392576, 1189251130666225664, 1182806388273307649, 729501876803149824, 1187554286517002246, 1187776048743628800, 796869950837243904, 1046662905976958976, 1186562143904325634, 142845220, 88134800, 1185937600361697280, 781009538153668610, 1004406993313042432, 839229596042153985, 1183894492694401024, 176287562, 454002922, 51990413, 961726729860648960, 4841079591, 514995886, 614631435, 1179056675858321410, 743031348131188736, 3139947645, 51497364, 1077726836367360001, 86304199, 827990244330979328, 2784762020, 823064382800297984, 1077340429010362369, 510088164, 1159783902925344769, 781358290164854784, 4324251556, 1174666062
# ...

# %%
#1.4 a

# %%
import tweepy
import csv
import json


CONSUMER_KEY = 'u7L1lnR7HN85dn1qnTFO1cegb'
CONSUMER_SECRET = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
access_token = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
access_secret = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(access_token, access_secret)

save_file = open('tweet_geo.json', 'w', encoding = 'utf8')


api = tweepy.API(auth, wait_on_rate_limit = True)



public_tweets = api.search(q= ['weather','texas'], lang='en', count = 100)
for tweet in public_tweets:
	save_file.write(str(tweet))
	print (tweet.user.screen_name, 'tweeted:', tweet.text)
# Out:
# _metar_bot_ tweeted: The current weather 50 minutes ago in EAGLE LAKE, TEXAS was drizzle.
#
# KELA 142015Z AUTO 02008KT 2 1/2SM DZ OVC005 0… https://t.co/4pY5IV2ql9
# UTDallasWeather tweeted: Weather over next 8 hours at University of Texas at Dallas (https://t.co/TKYhCY6ANe) #dfwwx #CometReady https://t.co/tdUqNth21T
# TXSpeedwayWx tweeted: Weather over next 8 hours at Texas Motor Speedway (https://t.co/jvOL7i6kpr) @TxMotorSpeedway https://t.co/g1nlGKDYT0
# TWUWeatherSTEM tweeted: Weather over next 8 hours at Texas Woman's University (https://t.co/MGXiLOawNo) https://t.co/TKB8u684ZZ
# teine1022 tweeted: Veterans are an important part of the Guild family. When severe weather threatened the Jensen Family's home, our se… https://t.co/q5QGY8YU8b
# ChadParmanMtg tweeted: Veterans are an important part of the Guild family. When severe weather threatened the Jensen Family's home, our se… https://t.co/z82846wdIj
# ...

# %%
##1.4 b

# %%
import tweepy
import csv
import json


CONSUMER_KEY = 'u7L1lnR7HN85dn1qnTFO1cegb'
CONSUMER_SECRET = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
access_token = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
access_secret = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(access_token, access_secret)

save_file = open('tweet_geo.json', 'w', encoding = 'utf8')


api = tweepy.API(auth, wait_on_rate_limit = True)

public_tweets_unt = api.search(q= '#unt', lang='en', count = 100, since_id = '2019-07-20', until_id= '2019-07-28' )
for tweet in public_tweets_unt:
	save_file.write(str(tweet))
	print (tweet.user.screen_name, 'tweeted:', tweet.text)

# %%
##1.4c

# %%
import tweepy
import csv
import json


CONSUMER_KEY = 'u7L1lnR7HN85dn1qnTFO1cegb'
CONSUMER_SECRET = 'QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT'
access_token = '1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO'
access_secret = 'gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce'


auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(access_token, access_secret)

save_file = open('tweet_geo.json', 'w', encoding = 'utf8')


api = tweepy.API(auth,wait_on_rate_limit = True, wait_on_rate_limit_notify= True)
public_tweets = tweepy.Cursor(api.search, count=100, geocode="-86.334163,-86.204174,5000km",show_user = True, lan= "eng").items()
for tweet in public_tweets:
	save_file.write(str(tweet))
	print(tweet.text)

# %%
## q 2 data collection for the parts 1, 2, 4

# %%
import pandas as pd
from matplotlib.pyplot import *

df = pd.read_csv('assignment_4_property_tax_report_2019.csv')
## i need dthe year_built ot include the year in a column and the number of house build in the other column so i can plot them
year_built = []
##loop through each row of the databse

#yearC = df.YEAR_BUILT
#print(yearC)
count = 0
year = 1900

while year < 2019:
	for row in df.YEAR_BUILT:
		if row == year:
			count = count +1
	year_built.append(count)

	count = 0
	year = year +1
	#year_built.append(count)
	




print (count)
print (year)
print (year_built)
#print (YEAR_BUILT)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e6530e2ce408> in <module>
#       2 from matplotlib.pyplot import *
#       3
# ----> 4 df = pd.read_csv('assignment_4_property_tax_report_2019.csv')
#       5 ## i need dthe year_built ot include the year in a column and the number of house build in the other column so i can plot them
#       6 year_built = []
#
# ...

# %%
q2 p1

# %%
plot(year_list,year_built)

# %%
##q2 part 2

# %%
ax = plt.gca()
ax.hist( year_built)



ax.set_xlabel('number of houses built')
ax.set_ylabel('frequency')

# %%
## q2 part 3

# %%
cat_name = ['Commercial', 'Comprehensive Development', 'Historic Area', 'Industrial', 'Light Industrial', 'Multiple Family Dwelling', 'One Family Dwelling', 'Two Family Dwelling']


cat_freq = []
counter = 0
for name in cat_name:
	for row in df.ZONE_CATEGORY:
		if row == name:
			counter = counter +1
			print()
	cat_freq.append(counter)
	counter = 0


print (cat_freq)




labels = 'Commercial', 'Comprehensive Development', 'Historic Area', 'Industrial', 'Light Industrial', 'Multiple Family Dwelling', 'One Family Dwelling', 'Two Family Dwelling'



pie(cat_freq, labels=labels, autopct='%1.1f%%', startangle=67)

title('top 8 cat')

# %%
## Q2 part 4

# %%
scatter(year_list, year_built )
